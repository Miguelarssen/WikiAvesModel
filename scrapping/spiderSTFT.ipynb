# %%
import requests
from bs4 import BeautifulSoup
import inspect
import json
import os   
from pathlib import Path
import pandas as pd
import re
import io
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display
import soundfile as sf

# %%
tamanhoDataset = 200

# %% [markdown]
# <h3>Neste trecho, uma url é analisada, retornando uma série de códigos de aves </h3>
#
# <p>Ainda não está finalizado. A ideia final é criar um algorítmo que possa iterar pela página, mapeando as espécies e jogando elas dentro da minha máquina</p>

# %%
def selectAves(FamiliaSelect):

    urlInfo="https://www.wikiaves.com.br/especies.php?t=t"

    # Está parte acessa a lista de espécies do wiki aves direto da página

    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/121.0.0.0 Safari/537.36"
        ),
        "Accept-Language": "pt-BR,pt;q=0.9",
        "Referer": "https://www.wikiaves.com.br/"
    }

    responseInfo = requests.get(urlInfo, headers=headers)
    soup = BeautifulSoup(responseInfo.content, "html.parser")

    soup = soup.find_all("table", class_="wa-table-sp table m-table m-table--head-separator-metal wa-table-hover")[0]
    aves = soup.find("tbody").find_all("script")[1:]

    # A lista das espécies está misturada com código html
    # Este trecho serve para limpar esta lista e transforma-la
    # em um dataframe pandas organizado

    avesDf = []

    # iteramos por item dentro do html
    for script in aves:
        texto = script.get_text(strip=True)
        
        # removemos a função "lsp" do html
        match = re.search(r"lsp\((.*)\);", texto)

        valores = []

        # fazemos separação dos valores por ,
        for v in match.group(1).split(","):
            v.strip().strip("'") 
            valores.append(v)

        # A listagem das espécies no site não lista a família da ave em todos os registros
        # apenas no primeiro registro que identifica aquela família, por isso o replicamos
        # para que no meu dataframe tenhamos a família da ave colocada corretamente nas colunas
        if valores[1] != " ''":
            familiaAtual = valores[1]

        else:
            valores[1] = familiaAtual
        
        avesDf.append({
            "codigo": int(valores[0].strip().strip("'")),
            "familia": valores[1].strip().strip("'") or None,
            "nome_cientifico": valores[2].strip().strip("'"),
            "nome_popular": valores[3].strip().strip("'"),
            "slug": valores[4].strip().strip("'"),
            "fotos": int(valores[5]),
            "sons": int(valores[6]),
        })

    avesDf = pd.DataFrame(avesDf)

    avesSelect = avesDf[
        (avesDf["familia"] == FamiliaSelect) &
        (avesDf["sons"] > tamanhoDataset)
    ][["codigo", "nome_popular"]]

    return avesSelect

# %% [markdown]
# <h3>função de pré processamento, para facilitar a leitura do código</h3>

# %%
def preProcess(audio, sr):
    TARGET_SECONDS = 5
    TARGET_SAMPLES = TARGET_SECONDS * sr

    FRAME_LEN = 2048
    HOP = 512

    # Calcula a média quadrática para detectar evento principal 
    # Esse código desloca uma janela de amostragem pelo áudio 
    # calculando a média de energia, assim podemos saber qual é
    # o trecho com mais atividade

    rms = librosa.feature.rms(
        y=audio,
        frame_length=FRAME_LEN,
        hop_length=HOP
    )[0]

    # Pegamos o trecho com mais atividade do retorno da função 
    # e então aplicamos essa multiplicação para removermos os 20% 
    # menos relevante do audio, assim eliminando uma faixa de ruído
    
    threshold = 0.2 * np.max(rms)
    frames_event = np.where(rms > threshold)[0]

    # Se não detectar evento (silêncio, erro, etc)
    if len(frames_event) == 0:
        return librosa.util.fix_length(audio, size=TARGET_SAMPLES)

    start_sample = librosa.frames_to_samples(frames_event[0], hop_length=HOP)
    end_sample   = librosa.frames_to_samples(frames_event[-1], hop_length=HOP)

    audio_event = audio[start_sample:end_sample]

    # Centraliza o evento na janela fixa
    if len(audio_event) >= TARGET_SAMPLES:
        audio_event = audio_event[:TARGET_SAMPLES]
    else:
        pad_total = TARGET_SAMPLES - len(audio_event)
        pad_left = pad_total // 2
        pad_right = pad_total - pad_left

        audio_event = np.pad(audio_event, (pad_left, pad_right))

    return audio_event

# %% [markdown]
# <h3>Aqui pegamos um código de ave diretamente, e então o transformamos em uma pasta com todos os seus sons disponíveis.</h3>

# %% [markdown]
# <h3>Aqui pegamos um código de ave diretamente, e então o transformamos em uma pasta com todos os seus sons disponíveis em formato npy</h3>

# %%
def createDataset(codigoAve, nomeAve, dwldLimit):
    # Essa url chama o endpoint /getRegistrosJSON.php
    # Os seus parâmetros, não conheço os detalhes de todos ainda
    # no entanto, eu sei que tm=s significa tipo mídia = som

    TARGET_SR = 44100  # sample rate fixo para todo o dataset

    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/121.0.0.0 Safari/537.36"
        ),
        "Accept-Language": "pt-BR,pt;q=0.9",
        "Referer": "https://www.wikiaves.com.br/"
    }

    dataset_path = Path("..") / "dataset" / nomeAve
    dataset_path.mkdir(parents=True, exist_ok=True)

    cont = 0
    page = 1

    while cont < dwldLimit:

        urlFiles = (
            "https://www.wikiaves.com.br/getRegistrosJSON.php?"
            f"tm=s&t=s&s={codigoAve}&o=mp&o=mp&p={page}"
        )

        responseFiles = requests.get(urlFiles, headers=headers)
        data = json.loads(responseFiles.text)["registros"]["itens"]

        # Se não veio nada, acabou o que o site tem
        if not data:
            print(f"Sem mais registros na página {page}")
            break

        for registro in data:
            link = data[registro]["link"]

            # Ainda não descobri como pegar diretamente o link dos sons em mp3,
            # ao invés dos espectrogramas diretamente, por isso, ao substituir
            # na url mp3 por jpg, podemos pegar os sons brutos
            link = link.replace(".jpg", ".mp3")

            # Por algum motivo, os links do s3 bucket com # são protegidos,
            # e sem o # são totalmente livres
            link = link.replace("#", "")

            try:
                responseAudio = requests.get(link, timeout=10)

                # Carrega o áudio SEM reamostrar
                audio, sr = librosa.load(
                    io.BytesIO(responseAudio.content),
                    sr=None,
                    mono=True
                )

                # Reamostragem explícita
                # Isso garante que TODOS os áudios estejam no mesmo domínio temporal
                if sr != TARGET_SR:
                    audio = librosa.resample(
                        audio,
                        orig_sr=sr,
                        target_sr=TARGET_SR
                    )
                    sr = TARGET_SR

                # Pré-processamento (RMS + centralização + 5s)
                audio = preProcess(audio, sr)

            except Exception as e:
                print(f"Erro no arquivo {registro}: {e}")
                continue

            # STFT com parâmetros fixos e sem padding automático
            stft = librosa.stft(
                audio,
                n_fft=2048,      # tamanho da FFT
                hop_length=512, # avanço da janela
                center=False    # evita padding implícito
            )

            stft_mag = np.abs(stft)
            stft_db = librosa.amplitude_to_db(stft_mag, ref=np.max)

            path = dataset_path / f"{nomeAve}_{cont}.npy"
            np.save(path, stft_db)

            cont += 1
            
        page+=1

# %% [markdown]
# Vamos usar a função que criamos, e iterar por avesSelect, assim fazedndo os downloads

# %%
avesSelect = selectAves("Columbidae")

for x in range(0, len(avesSelect)):
    #createDatasetAudio(avesSelect.iloc[x]["codigo"], avesSelect.iloc[x]["nome_popular"], tamanhoDataset)
    createDataset(avesSelect.iloc[x]["codigo"], avesSelect.iloc[x]["nome_popular"], tamanhoDataset)
# Out:
# Erro no arquivo 3: Error opening <_io.BytesIO object at 0x000001BFAE509DA0>: Format not recognised.
# Erro no arquivo 17: Error opening <_io.BytesIO object at 0x000001BFAE508E00>: Format not recognised.
# Erro no arquivo 5: Error opening <_io.BytesIO object at 0x000001BFAE55BB50>: Format not recognised.
# Erro no arquivo 9: Error opening <_io.BytesIO object at 0x000001BFAE55B3D0>: Format not recognised.
# Erro no arquivo 1: Error opening <_io.BytesIO object at 0x000001BFAE55BB50>: Format not recognised.
# Erro no arquivo 7: Error opening <_io.BytesIO object at 0x000001BFB011E020>: Format not recognised.
# Erro no arquivo 17: Error opening <_io.BytesIO object at 0x000001BFB011EDE0>: Format not recognised.
# Erro no arquivo 18: Error opening <_io.BytesIO object at 0x000001BFAE50A610>: Format not recognised.
# Erro no arquivo 18: Error opening <_io.BytesIO object at 0x000001BFB011F330>: Format not recognised.
# Erro no arquivo 15: Unspecified internal error.
# Erro no arquivo 2: Error opening <_io.BytesIO object at 0x000001BFAE4F67F0>: Format not recognised.
# Erro no arquivo 16: Error opening <_io.BytesIO object at 0x000001BF94DD96C0>: Format not recognised.
# Erro no arquivo 1: Error opening <_io.BytesIO object at 0x000001BFAE509DA0>: Format not recognised.
# Erro no arquivo 9: Error opening <_io.BytesIO object at 0x000001BFB011CC70>: Format not recognised.
# Erro no arquivo 5: Error opening <_io.BytesIO object at 0x000001BF94DD89F0>: Format not recognised.
# Erro no arquivo 8: Error opening <_io.BytesIO object at 0x000001BF94DDB9C0>: Format not recognised.
# Erro no arquivo 12: Error opening <_io.BytesIO object at 0x000001BFB011CC70>: Format not recognised.
# Erro no arquivo 20: Error opening <_io.BytesIO object at 0x000001BFAE508EF0>: Format not recognised.
# Erro no arquivo 2: Error opening <_io.BytesIO object at 0x000001BFB011EDE0>: Format not recognised.
# Erro no arquivo 18: Error opening <_io.BytesIO object at 0x000001BF94DDA390>: Format not recognised.
# Erro no arquivo 15: Error opening <_io.BytesIO object at 0x000001BF94DDB650>: Format not recognised.
# Erro no arquivo 16: Error opening <_io.BytesIO object at 0x000001BFAE50A610>: Format not recognised.
# Erro no arquivo 2: Error opening <_io.BytesIO object at 0x000001BFB011EDE0>: Format not recognised.
# Erro no arquivo 5: Error opening <_io.BytesIO object at 0x000001BFAE50A610>: Format not recognised.
# Erro no arquivo 12: Error opening <_io.BytesIO object at 0x000001BFAE508E00>: Format not recognised.
# Erro no arquivo 4: Error opening <_io.BytesIO object at 0x000001BFB011CE00>: Format not recognised.
# Erro no arquivo 6: Error opening <_io.BytesIO object at 0x000001BF94DDBC40>: Format not recognised.
# Erro no arquivo 10: Error opening <_io.BytesIO object at 0x000001BF94DDA840>: Format not recognised.
# Erro no arquivo 11: Error opening <_io.BytesIO object at 0x000001BFB011FAB0>: Format not recognised.
# Erro no arquivo 13: Error opening <_io.BytesIO object at 0x000001BF94DDBB50>: Format not recognised.
# Erro no arquivo 20: Error opening <_io.BytesIO object at 0x000001BFAE55BD80>: Format not recognised.
# Erro no arquivo 2: Error opening <_io.BytesIO object at 0x000001BFAE55BD80>: Format not recognised.
# Erro no arquivo 19: Error opening <_io.BytesIO object at 0x000001BFAE50A610>: Format not recognised.
# Erro no arquivo 6: Error opening <_io.BytesIO object at 0x000001BFB011CE00>: Format not recognised.
# Erro no arquivo 16: Error opening <_io.BytesIO object at 0x000001BFB011CE00>: Format not recognised.
# Erro no arquivo 14: Error opening <_io.BytesIO object at 0x000001BFB011CE00>: Format not recognised.
# Erro no arquivo 16: Error opening <_io.BytesIO object at 0x000001BF94DDB510>: Format not recognised.
# Erro no arquivo 18: Error opening <_io.BytesIO object at 0x000001BFAE508DB0>: Format not recognised.
# Erro no arquivo 9: Error opening <_io.BytesIO object at 0x000001BFAE4A2F70>: Format not recognised.
# Erro no arquivo 2: Error opening <_io.BytesIO object at 0x000001BFAE508E00>: Format not recognised.
# Erro no arquivo 15: Error opening <_io.BytesIO object at 0x000001BFB011E020>: Format not recognised.
# Erro no arquivo 7: Error opening <_io.BytesIO object at 0x000001BFB011CE00>: Format not recognised.
# Erro no arquivo 10: Error opening <_io.BytesIO object at 0x000001BFAE508E00>: Format not recognised.

# %%
avesSelect
# Out:
#      codigo            nome_popular
# 94    10395        pomba-asa-branca
# 97    10398            pomba-galega
# 98    10399          pomba-amargosa
# 100   10406                  pariri
# 102   10402             juriti-pupu
# 103   10403  juriti-de-testa-branca
# 104   10401                 avoante
# 105   10390             pararu-azul
# 109   10386            rolinha-roxa
# 110   10387     rolinha-fogo-apagou
# 111   10388           rolinha-picuí

# %%
def CreateEspectograms(especie): 

    # pasta onde estão os .npy
    DATASET_DIR = Path("../dataset/"+especie)

    # lista todos os arquivos .npy
    files = sorted(DATASET_DIR.glob("*.npy"))

    for file in files:
        spec = np.load(file)

        plt.figure(figsize=(10, 4))
        librosa.display.specshow(
            spec,
            #sr=sr,
            hop_length=512,
            x_axis="time",
            y_axis="hz"
        )
        plt.colorbar(format="%+2.0f dB")
        plt.title("Espectrograma (STFT)")
        plt.tight_layout()
        #plt.show()

        output_path = file.with_suffix(".jpg")
        plt.savefig(output_path, dpi=300)
        plt.close()
